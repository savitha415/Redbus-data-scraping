# %%
import pandas as pd

df1 = pd.read_csv("bus_data.csv")

df1
# Out:
#                                                    Link  \
# 0     https://www.redbus.in/bus-tickets/vijayawada-t...
# 1     https://www.redbus.in/bus-tickets/vijayawada-t...
# 2     https://www.redbus.in/bus-tickets/vijayawada-t...
# 3     https://www.redbus.in/bus-tickets/vijayawada-t...
# 4     https://www.redbus.in/bus-tickets/vijayawada-t...
# ...                                                 ...
# 5054  https://www.redbus.in/bus-tickets/hyderabad-to...
# 5055  https://www.redbus.in/bus-tickets/hyderabad-to...
# 5056  https://www.redbus.in/bus-tickets/hyderabad-to...
# 5057  https://www.redbus.in/bus-tickets/hyderabad-to...
# 5058  https://www.redbus.in/bus-tickets/hyderabad-to...
#
#                         Route        Bus Name  \
# 0     Vijayawada to Hyderabad   APSRTC - 3562
# 1     Vijayawada to Hyderabad   APSRTC - 3571
# 2     Vijayawada to Hyderabad   APSRTC - 3825
# 3     Vijayawada to Hyderabad   APSRTC - 3583
# 4     Vijayawada to Hyderabad   APSRTC - 3549
# ...

# %%
df1.head()
# Out:
#                                                 Link                    Route  \
# 0  https://www.redbus.in/bus-tickets/vijayawada-t...  Vijayawada to Hyderabad
# 1  https://www.redbus.in/bus-tickets/vijayawada-t...  Vijayawada to Hyderabad
# 2  https://www.redbus.in/bus-tickets/vijayawada-t...  Vijayawada to Hyderabad
# 3  https://www.redbus.in/bus-tickets/vijayawada-t...  Vijayawada to Hyderabad
# 4  https://www.redbus.in/bus-tickets/vijayawada-t...  Vijayawada to Hyderabad
#
#         Bus Name                                        Bus Type  \
# 0  APSRTC - 3562          SUPER LUXURY (NON-AC, 2 + 2 PUSH BACK)
# 1  APSRTC - 3571  DOLPHIN CRUISE (VOLVO / SCANIA A.C Multi Axle)
# 2  APSRTC - 3825          SUPER LUXURY (NON-AC, 2 + 2 PUSH BACK)
# 3  APSRTC - 3583      AMARAVATHI (VOLVO / SCANIA A.C Multi Axle)
# 4  APSRTC - 3549          SUPER LUXURY (NON-AC, 2 + 2 PUSH BACK)
#
#   Departing Time Reaching Time Duration Star Rating    Price  \
# ...

# %%
df1.drop(columns=['Link'])
# Out:
#                         Route        Bus Name  \
# 0     Vijayawada to Hyderabad   APSRTC - 3562
# 1     Vijayawada to Hyderabad   APSRTC - 3571
# 2     Vijayawada to Hyderabad   APSRTC - 3825
# 3     Vijayawada to Hyderabad   APSRTC - 3583
# 4     Vijayawada to Hyderabad   APSRTC - 3549
# ...                       ...             ...
# 5054    Hyderabad to Tirupati  Moksha Travels
# 5055    Hyderabad to Tirupati        Yolo Bus
# 5056    Hyderabad to Tirupati  Vikram Travels
# 5057    Hyderabad to Tirupati  Moksha Travels
# 5058    Hyderabad to Tirupati     CMR Express
#
#                                             Bus Type Departing Time  \
# 0             SUPER LUXURY (NON-AC, 2 + 2 PUSH BACK)          14:00
# 1     DOLPHIN CRUISE (VOLVO / SCANIA A.C Multi Axle)          14:00
# 2             SUPER LUXURY (NON-AC, 2 + 2 PUSH BACK)          14:30
# 3         AMARAVATHI (VOLVO / SCANIA A.C Multi Axle)          14:30
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5059 entries, 0 to 5058
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Link                5059 non-null   object
#  1   Route               5059 non-null   object
#  2   Bus Name            4000 non-null   object
#  3   Bus Type            3966 non-null   object
#  4   Departing Time      4000 non-null   object
#  5   Reaching Time       4000 non-null   object
#  6   Duration            4000 non-null   object
#  7   Star Rating         3999 non-null   object
#  8   Price               3999 non-null   object
#  9   Seats Availability  3985 non-null   object
# dtypes: object(10)
# memory usage: 395.4+ KB

# %%
df1['Price'] = df1['Price'].astype(str)
df1['Price'] = df1['Price'].str.replace('INR ', '').astype(float)
df1['Price'].fillna(0)
# Out:
# 0       436.0
# 1       720.0
# 2       469.0
# 3       720.0
# 4       436.0
#         ...
# 5054    950.0
# 5055    780.0
# 5056    969.0
# 5057    970.0
# 5058    745.0
# Name: Price, Length: 5059, dtype: float64

# %%
df1['Star Rating'] = df1['Star Rating'].str.split('\n').str[0]
df1['Star Rating'].fillna(0)
# Out:
# 0       2.7
# 1       4.1
# 2       2.8
# 3       3.8
# 4       4.6
#        ...
# 5054    4.4
# 5055    4.2
# 5056    4.6
# 5057    4.1
# 5058    4.1
# Name: Star Rating, Length: 5059, dtype: object

# %%
df1.isnull().sum()
# Out:
# Link                     0
# Route                    0
# Bus Name              1059
# Bus Type              1093
# Departing Time        1059
# Reaching Time         1059
# Duration              1059
# Star Rating           1060
# Price                 1060
# Seats Availability    1074
# dtype: int64

# %%
# Function to safely convert to float
def safe_float(value):
    try:
        return float(value)
    except ValueError:
        return None  # or another appropriate value, such as NaN

# Clean 'Star Rating' column
df1['Star Rating'] = df1['Star Rating'].apply(safe_float)

# %%
df1 = df1.dropna(subset=['Bus Name'])
df1 = df1.dropna(subset=['Bus Type'])
df1 = df1.dropna(subset=['Departing Time'])
df1 = df1.dropna(subset=['Reaching Time'])
df1 = df1.dropna(subset=['Duration'])
df1 = df1.dropna(subset=['Star Rating'])
df1 = df1.dropna(subset=['Price'])
df1 = df1.dropna(subset=['Seats Availability'])

# %%
df1.isnull().sum()
# Out:
# Link                  0
# Route                 0
# Bus Name              0
# Bus Type              0
# Departing Time        0
# Reaching Time         0
# Duration              0
# Star Rating           0
# Price                 0
# Seats Availability    0
# dtype: int64

# %%
import re
def extract_number(seat_str):
    match = re.search(r'\d+', seat_str)  # Find the first sequence of digits
    if match:
        return float(match.group(0))
    return 0  # Default value if no number is found

# %%
df1['Seats Availability'] = df1['Seats Availability'].apply(extract_number)

# %%
print(df1['Star Rating'].unique())
# Out:
# [2.7 4.1 2.8 3.8 4.6 3.7 4.  3.3 4.4 3.4 4.3 3.1 2.4 3.9 4.2 4.8 2.6 4.7
#  3.  4.5 3.6 2.2 2.9 3.5 4.9 2.1 1.7 1.5 2.3 2.5 3.2 1.9 1.8 2.  1.4 1.2
#  1.6 1.3 5.  1.  1.1]

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3950 entries, 0 to 5058
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Link                3950 non-null   object
#  1   Route               3950 non-null   object
#  2   Bus Name            3950 non-null   object
#  3   Bus Type            3950 non-null   object
#  4   Departing Time      3950 non-null   object
#  5   Reaching Time       3950 non-null   object
#  6   Duration            3950 non-null   object
#  7   Star Rating         3950 non-null   float64
#  8   Price               3950 non-null   float64
#  9   Seats Availability  3950 non-null   object
# dtypes: float64(2), object(8)
# memory usage: 339.5+ KB

# %%
df1.to_csv('cleaned_bus_data.csv', index=False)

# %%
df2=pd.read_csv("cleaned_bus_data.csv")
df2
# Out:
#                                                    Link  \
# 0     https://www.redbus.in/bus-tickets/vijayawada-t...
# 1     https://www.redbus.in/bus-tickets/vijayawada-t...
# 2     https://www.redbus.in/bus-tickets/vijayawada-t...
# 3     https://www.redbus.in/bus-tickets/vijayawada-t...
# 4     https://www.redbus.in/bus-tickets/vijayawada-t...
# ...                                                 ...
# 3945  https://www.redbus.in/bus-tickets/hyderabad-to...
# 3946  https://www.redbus.in/bus-tickets/hyderabad-to...
# 3947  https://www.redbus.in/bus-tickets/hyderabad-to...
# 3948  https://www.redbus.in/bus-tickets/hyderabad-to...
# 3949  https://www.redbus.in/bus-tickets/hyderabad-to...
#
#                         Route        Bus Name  \
# 0     Vijayawada to Hyderabad   APSRTC - 3562
# 1     Vijayawada to Hyderabad   APSRTC - 3571
# 2     Vijayawada to Hyderabad   APSRTC - 3825
# 3     Vijayawada to Hyderabad   APSRTC - 3583
# 4     Vijayawada to Hyderabad   APSRTC - 3549
# ...
